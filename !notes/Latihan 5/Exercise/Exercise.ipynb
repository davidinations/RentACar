# %% [markdown]
# ![image.png](attachment:image.png)

# %%
filmMu = input('Masukkan 5 Film Kesukaan anda dipisahkan dengan koma: ').title()
filmMu = filmMu.split(",")

print(set(filmMu))

filmTemanmu = input('Masukkan 5 Film Kesukaan teman anda dipisahkan dengan koma: ').title()
filmTemanmu = filmTemanmu.split(",")

print(set(filmTemanmu))

filmIrisan = set(filmMu).intersection(set(filmTemanmu))

persen = len(filmIrisan) / len(filmMu) * 100

print(f'Kesukaan Film kalian yang sama sebesar {persen}%')
# Out:
# {'Batman', 'Hulk', 'Iron Man 3', 'Wonder Woman ', 'Avengers'}
# {'Wonder Woman', 'Superman', 'Iron Man 3', 'Hulk', 'Avengers'}
