# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. {}<br>
# 2. {'foo': 42}<br>
# 3. a list is a collection of values while a dictionary is a collection of key-value pairs<br>
# 4. you get a KeyError error<br>
# 5. There is no difference. The `in` operator checks whether a value exists as a key in the dictionary.<br>
# 6. 'cat' in spam checks whether there is a 'cat' key in the dictionary, while 'cat' in spam.values() checks whether there is a value 'cat' for one of the keys in spam<br>
# 7. spam.setdefault('color', 'black')<br>

# %%
dict1 = {'foo': 42}
if 'foo' in dict1.keys():
    print('is a value in the dictionary')
else:
    print('is not a value in the dictionary')


for key in dict1.keys():
    print(key)

dict1['foo'] = 43
print(dict1)

# dict1['bar'] = 42
# print(dict1)

dict1.update({'bar': 43})
print(dict1)
# Out:
# is a value in the dictionary
# foo
# {'foo': 43}
# {'foo': 43, 'bar': 43}
